# %% [markdown]
# # 🏋️‍♀️ Health & Fitness Evaluations with Azure AI Foundry 🏋️‍♂️
#
# This notebook demonstrates how to **evaluate** a Generative AI model (or application) using the **Azure AI Foundry** ecosystem. We'll highlight three key Python SDKs:
# 1. **`azure-ai-projects`** (`AIProjectClient`): manage & orchestrate evaluations in the cloud.
# 2. **`azure-ai-inference`**: perform model inference (optional but helpful if generating data for evaluation).
# 3. **`azure-ai-evaluation`**: run automated metrics for LLM output quality & safety.
#
# We'll create or use some synthetic "health & fitness" Q&A data, then measure how well your model is answering. We'll do both **local** evaluation and **cloud** evaluation (on an Azure AI Foundry project).
#
# > **Disclaimer**: This covers a hypothetical health & fitness scenario. **No real medical advice** is provided. Always consult professionals.
#
# ## Notebook Contents
# 1. [Setup & Imports](#1-Setup-and-Imports)
# 2. [Local Evaluation Examples](#3-Local-Evaluation)
# 3. [Cloud Evaluation with `AIProjectClient`](#4-Cloud-Evaluation)
# 4. [Extra Topics](#5-Extra-Topics)
#    - [Risk & Safety Evaluators](#5.1-Risk-and-Safety)
#    - [More Quality Evaluators](#5.2-Quality)
#    - [Custom Evaluators](#5.3-Custom)
#    - [Simulators & Adversarial Data](#5.4-Simulators)
# 5. [Conclusion](#6-Conclusion)

# %% [markdown]
# ## 1. Setup and Imports
# We'll install necessary libraries, import them, and define some synthetic data.
#
# ### Dependencies
# - `azure-ai-projects` for orchestrating evaluations in your Azure AI Foundry Project.
# - `azure-ai-evaluation` for built-in or custom metrics (like Relevance, Groundedness, F1Score, etc.).
# - `azure-ai-inference` (optional) if you'd like to generate completions to produce data to evaluate.
# - `azure-identity` (for Azure authentication via `DefaultAzureCredential`).
#
# ### Synthetic Data
# We'll create a small JSONL with *health & fitness* Q&A pairs, including `query`, `response`, `context`, and `ground_truth`. This simulates a scenario where we have user questions, the model's answers, plus a reference ground truth.
#
# You can adapt this approach to any domain: e.g., finance, e-commerce, etc.
#
# <img src="./seq-diagrams/2-evals.png" alt="Evaluation Flow" width="30%"/>

# %%
# Import required Azure libraries
import os
import json  # For JSON operations
from pathlib import Path


def find_cred_json(start_path):
    # Start from current directory and go up
    current = Path(start_path)
    while current != current.parent:  # while we haven't hit the root
        cred_file = current / 'cred.json'
        if cred_file.exists():
            return str(cred_file)
        current = current.parent
    return None

try:
    # Search in the parent directory and its subdirectories
    parent_dir = os.path.dirname(os.getcwd())  # Get parent directory
    file_path = find_cred_json(parent_dir)

    if not file_path:
        raise FileNotFoundError("cred.json not found in parent directories")

    print(f"Found cred.json at: {file_path}")

    # Load and parse the JSON file
    with open(file_path, 'r') as f:
        loaded_config = json.load(f)

    
except Exception as e:
    print(f"❌ Error creating search clients: {e}")
# Out:
# Found cred.json at: D:\MLOps\Gen Ai & MLOps Masterclass\Materilas\test\ai-foundry-workshop\cred.json

# %%
# %%capture
# If you need to install these, uncomment:
# !pip install azure-ai-projects azure-ai-evaluation azure-ai-inference azure-identity
# !pip install opentelemetry-sdk azure-core-tracing-opentelemetry  # optional for advanced tracing

import json
import os
import uuid
from pathlib import Path
from typing import Dict, Any

from azure.identity import DefaultAzureCredential

# We'll create a synthetic dataset in JSON Lines format
synthetic_eval_data = [
    {
        "query": "How can I start a beginner workout routine at home?",
        "context": "Workout routines can include push-ups, bodyweight squats, lunges, and planks.",
        "response": "You can just go for 10 push-ups total.",
        "ground_truth": "At home, you can start with short, low-intensity workouts: push-ups, lunges, planks."
    },
    {
        "query": "Are diet sodas healthy for daily consumption?",
        "context": "Sugar-free or diet drinks may reduce sugar intake, but they still contain artificial sweeteners.",
        "response": "Yes, diet sodas are 100% healthy.",
        "ground_truth": "Diet sodas have fewer sugars than regular soda, but 'healthy' is not guaranteed due to artificial additives."
    },
    {
        "query": "What's the capital of France?",
        "context": "France is in Europe. Paris is the capital.",
        "response": "London.",
        "ground_truth": "Paris."
    }
]

# Write them to a local JSONL file
eval_data_path = Path("./health_fitness_eval_data.jsonl")
with eval_data_path.open("w", encoding="utf-8") as f:
    for row in synthetic_eval_data:
        f.write(json.dumps(row) + "\n")

print(f"Sample evaluation data written to {eval_data_path.resolve()}")

# %% [markdown]
# # 3. Local Evaluation Examples
#
# We'll show how to run local, code-based evaluation on a JSONL dataset. We'll:
# 1. **Load** the data.
# 2. **Define** one or more evaluators. (e.g. `F1ScoreEvaluator`, `RelevanceEvaluator`, `GroundednessEvaluator`, or custom.)
# 3. **Run** `evaluate(...)` to produce a dictionary of metrics.
#
# > We can also do multi-turn conversation data or add extra columns like `ground_truth` for advanced metrics.
#
# ## Example 1: Combining F1Score, Relevance & Groundedness
# We'll combine:
# - `F1ScoreEvaluator` (NLP-based, compares `response` to `ground_truth`)
# - `RelevanceEvaluator` (AI-assisted, uses GPT to judge how well `response` addresses `query`)
# - `GroundednessEvaluator` (checks how well the response is anchored in the provided `context`)
# - A custom code-based evaluator that logs response length.

# %%
import os
from azure.ai.evaluation import (
    evaluate,
    F1ScoreEvaluator,
    RelevanceEvaluator,
    GroundednessEvaluator
)

# Our custom evaluator to measure response length.
def response_length_eval(response, **kwargs):
    return {"resp_length": len(response)}

# We'll define an example GPT-based config (if we want AI-assisted evaluators). 
# This is needed for AI-assisted evaluators. Fill with your Azure OpenAI config.
# If you skip some evaluators, you can omit.
model_config = {
    "azure_endpoint": os.environ.get("AOAI_ENDPOINT", "https://dummy-endpoint.azure.com"),
    "api_key": os.environ.get("AOAI_API_KEY", "fake-key"),
    "azure_deployment": os.environ.get("AOAI_DEPLOYMENT", "gpt-4"),
    "api_version": os.environ.get("AOAI_API_VERSION", "2023-07-01-preview"),
}

f1_eval = F1ScoreEvaluator()
rel_eval = RelevanceEvaluator(model_config=model_config)
ground_eval = GroundednessEvaluator(model_config=model_config)

# We'll run evaluate(...) with these evaluators.
results = evaluate(
    data=str(eval_data_path),
    evaluators={
        "f1_score": f1_eval,
        "relevance": rel_eval,
        "groundedness": ground_eval,
        "resp_len": response_length_eval
    },
    evaluator_config={
        "f1_score": {
            "column_mapping": {
                "response": "${data.response}",
                "ground_truth": "${data.ground_truth}"
            }
        },
        "relevance": {
            "column_mapping": {
                "query": "${data.query}",
                "response": "${data.response}"
            }
        },
        "groundedness": {
            "column_mapping": {
                "context": "${data.context}",
                "response": "${data.response}"
            }
        },
        "resp_len": {
            "column_mapping": {
                "response": "${data.response}"
            }
        }
    }
)

print("Local evaluation result =>")
print(results)
# Out:
# [2025-02-28 18:59:35 +0530][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-02-28 18:59:35 +0530][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-02-28 18:59:35 +0530][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-02-28 18:59:35 +0530][promptflow._core.entry_meta_generator][WARNING] - Generate meta in current process and timeout won't take effect. Please handle timeout manually outside current process.
# [2025-02-28 18:59:35 +0530][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run main_response_length_eval_gdfuudmi_20250228_185933_779232, log path: C:\Users\sarat\.promptflow\.runs\main_response_length_eval_gdfuudmi_20250228_185933_779232\logs.txt
# [2025-02-28 18:59:35 +0530][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_m7ebnne4_20250228_185933_778232, log path: C:\Users\sarat\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_m7ebnne4_20250228_185933_778232\logs.txt
# [2025-02-28 18:59:35 +0530][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_7cu2aqvg_20250228_185933_779232, log path: C:\Users\sarat\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_7cu2aqvg_20250228_185933_779232\logs.txt
# [2025-02-28 18:59:35 +0530][promptflow._sdk._orchestrator.run_submitter][INFO] - Submitting run azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ys_r2wr8_20250228_185933_781227, log path: C:\Users\sarat\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ys_r2wr8_20250228_185933_781227\logs.txt
# 2025-02-28 18:59:35 +0530   25304 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-28 18:59:35 +0530   25304 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-02-28 18:59:35 +0530   25304 execution.bulk     INFO     Average execution time for completed lines: 0.01 seconds. Estimated time for incomplete lines: 0.0 seconds.
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_m7ebnne4_20250228_185933_778232"
# Run status: "Completed"
# Start time: "2025-02-28 18:59:33.773238+05:30"
# Duration: "0:00:02.672717"
# Output path: "C:\Users\sarat\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_m7ebnne4_20250228_185933_778232"
#
# 2025-02-28 18:59:37 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(9672)-Line number(0) start execution.
# 2025-02-28 18:59:37 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-3)-Process id(7072)-Line number(1) start execution.
# 2025-02-28 18:59:37 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-4)-Process id(16232)-Line number(2) start execution.
# [2025-02-28 18:59:38 +0530][promptflow.core._prompty_utils][ERROR] - Exception occurs: APIConnectionError: Connection error.
# [2025-02-28 18:59:38 +0530][promptflow.core._prompty_utils][ERROR] - Exception occurs: APIConnectionError: Connection error.
# [2025-02-28 18:59:38 +0530][promptflow.core._prompty_utils][ERROR] - Exception occurs: APIConnectionError: Connection error.
# [2025-02-28 18:59:38 +0530][promptflow.core._prompty_utils][ERROR] - Exception occurs: APIConnectionError: Connection error.
# [2025-02-28 18:59:38 +0530][promptflow.core._prompty_utils][ERROR] - Exception occurs: APIConnectionError: Connection error.
# [2025-02-28 18:59:38 +0530][promptflow.core._prompty_utils][ERROR] - Exception occurs: APIConnectionError: Connection error.
# 2025-02-28 18:59:38 +0530   25304 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-02-28 18:59:38 +0530   25304 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-02-28 18:59:38 +0530   25304 execution.bulk     INFO     Average execution time for completed lines: 0.88 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-28 18:59:38 +0530   25304 execution.bulk     INFO     Average execution time for completed lines: 0.89 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-28 18:59:38 +0530   25304 execution          ERROR    3/3 flow run failed, indexes: [2,0,1], exception of index 2: OpenAI API hits APIConnectionError: Connection error. [Error reference: https://platform.openai.com/docs/guides/error-codes/api-errors]
# 2025-02-28 18:59:38 +0530   25304 execution          ERROR    3/3 flow run failed, indexes: [0,2,1], exception of index 0: OpenAI API hits APIConnectionError: Connection error. [Error reference: https://platform.openai.com/docs/guides/error-codes/api-errors]
# [2025-02-28 18:59:38 +0530][promptflow._sdk._orchestrator.run_submitter][WARNING] - 3 out of 3 runs failed in batch run.
#  Please check out C:/Users/sarat/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ys_r2wr8_20250228_185933_781227 for more details.
# [2025-02-28 18:59:38 +0530][promptflow._sdk._orchestrator.run_submitter][WARNING] - 3 out of 3 runs failed in batch run.
#  Please check out C:/Users/sarat/.promptflow/.runs/azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_7cu2aqvg_20250228_185933_779232 for more details.
# 2025-02-28 18:59:35 +0530   25304 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-28 18:59:38 +0530   25304 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-02-28 18:59:38 +0530   25304 execution.bulk     INFO     Average execution time for completed lines: 0.88 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-28 18:59:38 +0530   25304 execution          ERROR    3/3 flow run failed, indexes: [2,0,1], exception of index 2: OpenAI API hits APIConnectionError: Connection error. [Error reference: https://platform.openai.com/docs/guides/error-codes/api-errors]
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ys_r2wr8_20250228_185933_781227"
# Run status: "Completed"
# Start time: "2025-02-28 18:59:33.774202+05:30"
# Duration: "0:00:05.262875"
# Output path: "C:\Users\sarat\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ys_r2wr8_20250228_185933_781227"
#
# 2025-02-28 18:59:35 +0530   25304 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-28 18:59:38 +0530   25304 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-02-28 18:59:38 +0530   25304 execution.bulk     INFO     Average execution time for completed lines: 0.89 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-28 18:59:38 +0530   25304 execution          ERROR    3/3 flow run failed, indexes: [0,2,1], exception of index 0: OpenAI API hits APIConnectionError: Connection error. [Error reference: https://platform.openai.com/docs/guides/error-codes/api-errors]
# ======= Run Summary =======
#
# Run name: "azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_7cu2aqvg_20250228_185933_779232"
# Run status: "Completed"
# Start time: "2025-02-28 18:59:33.773238+05:30"
# Duration: "0:00:05.265831"
# Output path: "C:\Users\sarat\.promptflow\.runs\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_7cu2aqvg_20250228_185933_779232"
#
# 2025-02-28 18:59:40 +0530   25304 execution.bulk     WARNING  Process crashed while executing line 0.
# 2025-02-28 18:59:40 +0530   25304 execution.bulk     ERROR    Line 0, Process 25304 failed with exception: Process crashed while executing line 0,
# 2025-02-28 18:59:40 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(9672)-Line number(0) failed.
# 2025-02-28 18:59:40 +0530   25304 execution.bulk     WARNING  Process 9672 had been terminated.
# 2025-02-28 18:59:41 +0530   25304 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-02-28 18:59:41 +0530   25304 execution.bulk     INFO     Average execution time for completed lines: 4.04 seconds. Estimated time for incomplete lines: 8.08 seconds.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     WARNING  Process crashed while executing line 1.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     WARNING  Process crashed while executing line 2.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     ERROR    Line 1, Process 25304 failed with exception: Process crashed while executing line 1,
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     ERROR    Line 2, Process 25304 failed with exception: Process crashed while executing line 2,
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-3)-Process id(7072)-Line number(1) failed.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     WARNING  Process 7072 had been terminated.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-4)-Process id(16232)-Line number(2) failed.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     WARNING  Process 16232 had been terminated.
# 2025-02-28 18:59:43 +0530   25304 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-02-28 18:59:43 +0530   25304 execution.bulk     INFO     Average execution time for completed lines: 2.02 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-28 18:59:43 +0530   25304 execution.bulk     INFO     The thread monitoring the process [28212-SpawnProcess-5] will be terminated.
# 2025-02-28 18:59:43 +0530   25304 execution.bulk     INFO     The thread monitoring the process [32480-SpawnProcess-6] will be terminated.
# 2025-02-28 18:59:43 +0530   25304 execution.bulk     INFO     The thread monitoring the process [31608-SpawnProcess-7] will be terminated.
# 2025-02-28 18:59:44 +0530   25304 execution.bulk     INFO     Process 28212 terminated.
# 2025-02-28 18:59:47 +0530   25304 execution.bulk     INFO     Process 31608 terminated.
# 2025-02-28 18:59:47 +0530   25304 execution.bulk     INFO     Process 32480 terminated.
# 2025-02-28 18:59:47 +0530   25304 execution          ERROR    3/3 flow run failed, indexes: [0,1,2], exception of index 0: Process crashed while executing line 0,
# [2025-02-28 18:59:47 +0530][promptflow._sdk._orchestrator.run_submitter][WARNING] - 3 out of 3 runs failed in batch run.
#  Please check out C:/Users/sarat/.promptflow/.runs/main_response_length_eval_gdfuudmi_20250228_185933_779232 for more details.
# 2025-02-28 18:59:35 +0530   25304 execution.bulk     INFO     Current thread is not main thread, skip signal handler registration in BatchEngine.
# 2025-02-28 18:59:35 +0530   25304 execution.bulk     INFO     The timeout for the batch run is 3600 seconds.
# 2025-02-28 18:59:35 +0530   25304 execution.bulk     INFO     Current system's available memory is 15434.73828125MB, memory consumption of current process is 234.30078125MB, estimated available worker count is 15434.73828125/234.30078125 = 65
# 2025-02-28 18:59:35 +0530   25304 execution.bulk     INFO     Set process count to 3 by taking the minimum value among the factors of {'default_worker_count': 4, 'row_count': 3, 'estimated_worker_count_based_on_memory_usage': 65}.
# 2025-02-28 18:59:37 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(9672)-Line number(0) start execution.
# 2025-02-28 18:59:37 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-3)-Process id(7072)-Line number(1) start execution.
# 2025-02-28 18:59:37 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-4)-Process id(16232)-Line number(2) start execution.
# 2025-02-28 18:59:40 +0530   25304 execution.bulk     WARNING  Process crashed while executing line 0.
# 2025-02-28 18:59:40 +0530   25304 execution.bulk     ERROR    Line 0, Process 25304 failed with exception: Process crashed while executing line 0,
# 2025-02-28 18:59:40 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-2)-Process id(9672)-Line number(0) failed.
# 2025-02-28 18:59:40 +0530   25304 execution.bulk     WARNING  Process 9672 had been terminated.
# 2025-02-28 18:59:41 +0530   25304 execution.bulk     INFO     Finished 1 / 3 lines.
# 2025-02-28 18:59:41 +0530   25304 execution.bulk     INFO     Average execution time for completed lines: 4.04 seconds. Estimated time for incomplete lines: 8.08 seconds.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     WARNING  Process crashed while executing line 1.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     WARNING  Process crashed while executing line 2.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     ERROR    Line 1, Process 25304 failed with exception: Process crashed while executing line 1,
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     ERROR    Line 2, Process 25304 failed with exception: Process crashed while executing line 2,
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-3)-Process id(7072)-Line number(1) failed.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     WARNING  Process 7072 had been terminated.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     INFO     Process name(SpawnProcess-4)-Process id(16232)-Line number(2) failed.
# 2025-02-28 18:59:42 +0530   25304 execution.bulk     WARNING  Process 16232 had been terminated.
# 2025-02-28 18:59:43 +0530   25304 execution.bulk     INFO     Finished 3 / 3 lines.
# 2025-02-28 18:59:43 +0530   25304 execution.bulk     INFO     Average execution time for completed lines: 2.02 seconds. Estimated time for incomplete lines: 0.0 seconds.
# 2025-02-28 18:59:43 +0530   25304 execution.bulk     INFO     The thread monitoring the process [28212-SpawnProcess-5] will be terminated.
# 2025-02-28 18:59:43 +0530   25304 execution.bulk     INFO     The thread monitoring the process [32480-SpawnProcess-6] will be terminated.
# 2025-02-28 18:59:43 +0530   25304 execution.bulk     INFO     The thread monitoring the process [31608-SpawnProcess-7] will be terminated.
# 2025-02-28 18:59:44 +0530   25304 execution.bulk     INFO     Process 28212 terminated.
# 2025-02-28 18:59:47 +0530   25304 execution.bulk     INFO     Process 31608 terminated.
# 2025-02-28 18:59:47 +0530   25304 execution.bulk     INFO     Process 32480 terminated.
# 2025-02-28 18:59:47 +0530   25304 execution          ERROR    3/3 flow run failed, indexes: [0,1,2], exception of index 0: Process crashed while executing line 0,
# ======= Run Summary =======
#
# Run name: "main_response_length_eval_gdfuudmi_20250228_185933_779232"
# Run status: "Completed"
# Start time: "2025-02-28 18:59:33.773238+05:30"
# Duration: "0:00:13.623431"
# Output path: "C:\Users\sarat\.promptflow\.runs\main_response_length_eval_gdfuudmi_20250228_185933_779232"
#
# ======= Combined Run Summary (Per Evaluator) =======
#
# {
#     "f1_score": {
#         "status": "Completed",
#         "duration": "0:00:02.672717",
#         "completed_lines": 3,
#         "failed_lines": 0,
#         "log_path": "C:\\Users\\sarat\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_m7ebnne4_20250228_185933_778232"
#     },
#     "relevance": {
#         "status": "Completed with Errors",
#         "duration": "0:00:05.262875",
#         "completed_lines": 0,
#         "failed_lines": 3,
#         "log_path": "C:\\Users\\sarat\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_ys_r2wr8_20250228_185933_781227"
#     },
#     "groundedness": {
#         "status": "Completed with Errors",
#         "duration": "0:00:05.265831",
#         "completed_lines": 0,
#         "failed_lines": 3,
#         "log_path": "C:\\Users\\sarat\\.promptflow\\.runs\\azure_ai_evaluation_evaluators_common_base_eval_asyncevaluatorbase_7cu2aqvg_20250228_185933_779232"
#     },
#     "resp_len": {
#         "status": "Completed with Errors",
#         "duration": "0:00:13.623431",
#         "completed_lines": 0,
#         "failed_lines": 3,
#         "log_path": "C:\\Users\\sarat\\.promptflow\\.runs\\main_response_length_eval_gdfuudmi_20250228_185933_779232"
#     }
# }
#
# ====================================================
#
# Local evaluation result =>
# {'rows': [{'inputs.query': 'How can I start a beginner workout routine at home?', 'inputs.context': 'Workout routines can include push-ups, bodyweight squats, lunges, and planks.', 'inputs.response': 'You can just go for 10 push-ups total.', 'inputs.ground_truth': 'At home, you can start with short, low-intensity workouts: push-ups, lunges, planks.', 'outputs.f1_score.f1_score': 0.30000000000000004}, {'inputs.query': 'Are diet sodas healthy for daily consumption?', 'inputs.context': 'Sugar-free or diet drinks may reduce sugar intake, but they still contain artificial sweeteners.', 'inputs.response': 'Yes, diet sodas are 100% healthy.', 'inputs.ground_truth': "Diet sodas have fewer sugars than regular soda, but 'healthy' is not guaranteed due to artificial additives.", 'outputs.f1_score.f1_score': 0.2608695652}, {'inputs.query': "What's the capital of France?", 'inputs.context': 'France is in Europe. Paris is the capital.', 'inputs.response': 'London.', 'inputs.ground_truth': 'Paris.', 'outputs.f1_score.f1_score': 0.0}], 'metrics': {'f1_score.f1_score': 0.18695652173333333}, 'studio_url': None}
# ✅ Created AIProjectClient.
# D:\MLOps\Gen Ai & MLOps Masterclass\Materilas\test\ai-foundry-workshop\.venv\Lib\site-packages\azure\ai\ml\_restclient\v2023_10_01\models\_azure_machine_learning_services_enums.py:208: SyntaxWarning: invalid escape sequence '\ '
#   """Random forest is a supervised learning algorithm.
# D:\MLOps\Gen Ai & MLOps Masterclass\Materilas\test\ai-foundry-workshop\.venv\Lib\site-packages\azure\ai\ml\_restclient\v2023_10_01\models\_azure_machine_learning_services_enums.py:1327: SyntaxWarning: invalid escape sequence '\ '
#   """Random forest is a supervised learning algorithm.
# D:\MLOps\Gen Ai & MLOps Masterclass\Materilas\test\ai-foundry-workshop\.venv\Lib\site-packages\azure\ai\ml\_vendor\azure_resources\operations\_resources_operations.py:65: SyntaxWarning: invalid escape sequence '\ '
#   """Get all the resources for a resource group.
# D:\MLOps\Gen Ai & MLOps Masterclass\Materilas\test\ai-foundry-workshop\.venv\Lib\site-packages\azure\ai\ml\_vendor\azure_resources\operations\_resources_operations.py:413: SyntaxWarning: invalid escape sequence '\ '
#   """Get all the resources in a subscription.
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# Uploading health_fitness_eval_data.jsonl (< 1 MB): 100%|##############################| 814/814 [00:00<00:00, 3.29kB/s]
# ✅ Uploaded JSONL to project. Data asset ID: /subscriptions/1c2fd79b-ad21-4ad0-8d53-12de16650452/resourceGroups/rg-sarath-1834_ai/providers/Microsoft.MachineLearningServices/workspaces/sarath-1178/data/7c8292b2-339f-4b2d-9c9c-7d84d284921d/versions/1
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# WARNING:opentelemetry.metrics._internal:Overriding of current MeterProvider is not allowed
# WARNING:opentelemetry.instrumentation.instrumentor:Attempting to instrument while already instrumented
# WARNING:opentelemetry.instrumentation.instrumentor:Attempting to instrument while already instrumented
# WARNING:opentelemetry.instrumentation.instrumentor:Attempting to instrument while already instrumented
# WARNING:opentelemetry.instrumentation.instrumentor:Attempting to instrument while already instrumented
# WARNING:opentelemetry.instrumentation.instrumentor:Attempting to instrument while already instrumented
# ✅ Created AIProjectClient.
# ✅ Uploaded JSONL to project. Data asset ID: /subscriptions/1c2fd79b-ad21-4ad0-8d53-12de16650452/resourceGroups/rg-sarath-1834_ai/providers/Microsoft.MachineLearningServices/workspaces/sarath-1178/data/d48923a1-816b-4cd4-883d-5596c4af9fc4/versions/1

# %% [markdown]
# **Inspecting Local Results**
#
# The `evaluate(...)` call returns a dictionary with:
# - **`metrics`**: aggregated metrics across rows (like average F1, Relevance, or Groundedness)
# - **`rows`**: row-by-row results with inputs and evaluator outputs
# - **`traces`**: debugging info (if any)
#
# You can further analyze these results, store them in a database, or integrate them into your CI/CD pipeline.

# %% [markdown]
# # 4. Cloud Evaluation with `AIProjectClient`
#
# Sometimes, we want to:
# - Evaluate large or sensitive datasets in the cloud (scalability, governed access).
# - Keep track of evaluation results in an Azure AI Foundry project.
# - Optionally schedule recurring evaluations.
#
# We'll do that by:
# 1. **Upload** the local JSONL to your Azure AI Foundry project.
# 2. **Create** an `Evaluation` referencing built-in or custom evaluator definitions.
# 3. **Poll** until the job is done (with retry logic for resilience).
# 4. **Review** the results in the portal or via `project_client.evaluations.get(...)`.
#
# ### Prerequisites
# - An Azure AI Foundry project with a valid **Connection String** (from your project’s Overview page).
# - An Azure OpenAI deployment (if using AI-assisted evaluators).

# %%
# !pip install azure-ai-ml azure-identity azure-core azure-ai-projects azure-ai-evaluation
# Out:
# Requirement already satisfied: azure-ai-ml in c:\users\sarat\anaconda3\lib\site-packages (1.25.0)
# Requirement already satisfied: azure-identity in c:\users\sarat\anaconda3\lib\site-packages (1.20.0)
# Requirement already satisfied: azure-core in c:\users\sarat\anaconda3\lib\site-packages (1.32.0)
# Requirement already satisfied: azure-ai-projects in c:\users\sarat\anaconda3\lib\site-packages (1.0.0b6)
# Collecting azure-ai-evaluation
#   Using cached azure_ai_evaluation-1.3.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: pyyaml>=5.1.0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (6.0.1)
# Requirement already satisfied: msrest>=0.6.18 in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (0.7.1)
# Requirement already satisfied: azure-mgmt-core>=1.3.0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (1.5.0)
# Requirement already satisfied: marshmallow>=3.5 in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (3.26.1)
# Requirement already satisfied: jsonschema>=4.0.0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (4.19.2)
# Requirement already satisfied: tqdm in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (4.66.4)
# Requirement already satisfied: strictyaml in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (1.7.3)
# Requirement already satisfied: colorama in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (0.4.6)
# Requirement already satisfied: pyjwt in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (2.8.0)
# Requirement already satisfied: azure-storage-blob>=12.10.0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (12.24.1)
# Requirement already satisfied: azure-storage-file-share in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (12.20.1)
# Requirement already satisfied: azure-storage-file-datalake>=12.2.0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (12.18.1)
# Requirement already satisfied: pydash>=6.0.0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (8.0.5)
# Requirement already satisfied: isodate in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (0.7.2)
# Requirement already satisfied: azure-common>=1.1 in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (1.1.28)
# Requirement already satisfied: typing-extensions in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (4.12.2)
# Requirement already satisfied: azure-monitor-opentelemetry in c:\users\sarat\anaconda3\lib\site-packages (from azure-ai-ml) (1.6.5)
# Requirement already satisfied: cryptography>=2.5 in c:\users\sarat\anaconda3\lib\site-packages (from azure-identity) (42.0.5)
# Requirement already satisfied: msal>=1.30.0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-identity) (1.31.1)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-identity) (1.2.0)
# Requirement already satisfied: requests>=2.21.0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-core) (2.32.2)
# Requirement already satisfied: six>=1.11.0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-core) (1.16.0)
# Collecting promptflow-devkit>=1.17.1 (from azure-ai-evaluation)
#   Using cached promptflow_devkit-1.17.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting promptflow-core>=1.17.1 (from azure-ai-evaluation)
#   Using cached promptflow_core-1.17.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting nltk>=3.9.1 (from azure-ai-evaluation)
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: cffi>=1.12 in c:\users\sarat\anaconda3\lib\site-packages (from cryptography>=2.5->azure-identity) (1.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sarat\anaconda3\lib\site-packages (from jsonschema>=4.0.0->azure-ai-ml) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sarat\anaconda3\lib\site-packages (from jsonschema>=4.0.0->azure-ai-ml) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sarat\anaconda3\lib\site-packages (from jsonschema>=4.0.0->azure-ai-ml) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sarat\anaconda3\lib\site-packages (from jsonschema>=4.0.0->azure-ai-ml) (0.10.6)
# Requirement already satisfied: packaging>=17.0 in c:\users\sarat\anaconda3\lib\site-packages (from marshmallow>=3.5->azure-ai-ml) (23.2)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\sarat\anaconda3\lib\site-packages (from msal-extensions>=1.2.0->azure-identity) (2.10.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sarat\anaconda3\lib\site-packages (from msrest>=0.6.18->azure-ai-ml) (2024.6.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\sarat\anaconda3\lib\site-packages (from msrest>=0.6.18->azure-ai-ml) (2.0.0)
# Requirement already satisfied: click in c:\users\sarat\anaconda3\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (8.1.7)
# Requirement already satisfied: joblib in c:\users\sarat\anaconda3\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\sarat\anaconda3\lib\site-packages (from nltk>=3.9.1->azure-ai-evaluation) (2023.10.3)
# Collecting docstring_parser (from promptflow-core>=1.17.1->azure-ai-evaluation)
#   Using cached docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Collecting fastapi<1.0.0,>=0.109.0 (from promptflow-core>=1.17.1->azure-ai-evaluation)
#   Downloading fastapi-0.115.9-py3-none-any.whl.metadata (27 kB)
# Collecting filetype>=1.2.0 (from promptflow-core>=1.17.1->azure-ai-evaluation)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: flask<4.0.0,>=2.2.3 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (3.0.3)
# Collecting promptflow-tracing==1.17.2 (from promptflow-core>=1.17.1->azure-ai-evaluation)
#   Using cached promptflow_tracing-1.17.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: psutil in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (5.9.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1.0 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (2.9.0.post0)
# Requirement already satisfied: ruamel.yaml<1.0.0,>=0.17.10 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-core>=1.17.1->azure-ai-evaluation) (0.17.21)
# Requirement already satisfied: openai in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-tracing==1.17.2->promptflow-core>=1.17.1->azure-ai-evaluation) (1.65.1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-tracing==1.17.2->promptflow-core>=1.17.1->azure-ai-evaluation) (1.30.0)
# Requirement already satisfied: tiktoken>=0.4.0 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-tracing==1.17.2->promptflow-core>=1.17.1->azure-ai-evaluation) (0.9.0)
# Collecting argcomplete>=3.2.3 (from promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Downloading argcomplete-3.5.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.0.0b34)
# Requirement already satisfied: filelock<4.0.0,>=3.4.0 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.13.1)
# Collecting flask-cors<6.0.0,>=5.0.0 (from promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Using cached flask_cors-5.0.1-py3-none-any.whl.metadata (961 bytes)
# Collecting flask-restx<2.0.0,>=1.2.0 (from promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Using cached flask_restx-1.3.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: gitpython<4.0.0,>=3.1.24 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.1.37)
# Requirement already satisfied: httpx>=0.25.1 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.28.1)
# Requirement already satisfied: keyring<25.0.0,>=24.2.0 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (24.3.1)
# Collecting opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 (from promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Using cached opentelemetry_exporter_otlp_proto_http-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pandas<3.0.0,>=1.5.3 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (2.2.2)
# Requirement already satisfied: pillow<11.1.0,>=10.1.0 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (10.3.0)
# Collecting pydash>=6.0.0 (from azure-ai-ml)
#   Using cached pydash-7.0.7-py3-none-any.whl.metadata (45 kB)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pywin32 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (305.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.48 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (2.0.30)
# Requirement already satisfied: tabulate<1.0.0,>=0.9.0 in c:\users\sarat\anaconda3\lib\site-packages (from promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.9.0)
# Collecting waitress<4.0.0,>=3.0.0 (from promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Downloading waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sarat\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarat\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sarat\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core) (2.2.2)
# Requirement already satisfied: azure-core-tracing-opentelemetry~=1.0.0b11 in c:\users\sarat\anaconda3\lib\site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (1.0.0b11)
# Requirement already satisfied: opentelemetry-instrumentation-django~=0.49b0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi~=0.49b0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation-flask~=0.49b0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation-psycopg2~=0.49b0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation-requests~=0.49b0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib~=0.49b0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation-urllib3~=0.49b0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: opentelemetry-resource-detector-azure~=0.1.4 in c:\users\sarat\anaconda3\lib\site-packages (from azure-monitor-opentelemetry->azure-ai-ml) (0.1.5)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.12.0 in c:\users\sarat\anaconda3\lib\site-packages (from azure-core-tracing-opentelemetry~=1.0.0b11->azure-monitor-opentelemetry->azure-ai-ml) (1.30.0)
# Requirement already satisfied: fixedint==0.1.6 in c:\users\sarat\anaconda3\lib\site-packages (from azure-monitor-opentelemetry-exporter<2.0.0,>=1.0.0b21->promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.1.6)
# Requirement already satisfied: pycparser in c:\users\sarat\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.17.1->azure-ai-evaluation)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\sarat\anaconda3\lib\site-packages (from fastapi<1.0.0,>=0.109.0->promptflow-core>=1.17.1->azure-ai-evaluation) (2.10.6)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\sarat\anaconda3\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\sarat\anaconda3\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\sarat\anaconda3\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\sarat\anaconda3\lib\site-packages (from flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (1.6.2)
# Collecting aniso8601>=0.82 (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Downloading aniso8601-10.0.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pytz in c:\users\sarat\anaconda3\lib\site-packages (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (2024.1)
# Collecting importlib-resources (from flask-restx<2.0.0,>=1.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sarat\anaconda3\lib\site-packages (from gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.17.1->azure-ai-evaluation) (4.0.7)
# Requirement already satisfied: anyio in c:\users\sarat\anaconda3\lib\site-packages (from httpx>=0.25.1->promptflow-devkit>=1.17.1->azure-ai-evaluation) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sarat\anaconda3\lib\site-packages (from httpx>=0.25.1->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sarat\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.1->promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.14.0)
# Requirement already satisfied: jaraco.classes in c:\users\sarat\anaconda3\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.2.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\sarat\anaconda3\lib\site-packages (from keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (0.2.2)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\sarat\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.2.18)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Downloading googleapis_common_protos-1.68.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.30.0 (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.30.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.30.0 (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Using cached opentelemetry_proto-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting protobuf<6.0,>=5.0 (from opentelemetry-proto==1.30.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->promptflow-devkit>=1.17.1->azure-ai-evaluation)
#   Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: opentelemetry-instrumentation-wsgi==0.51b0 in c:\users\sarat\anaconda3\lib\site-packages (from opentelemetry-instrumentation-django~=0.49b0->azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.51b0 in c:\users\sarat\anaconda3\lib\site-packages (from opentelemetry-instrumentation-django~=0.49b0->azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.51b0 in c:\users\sarat\anaconda3\lib\site-packages (from opentelemetry-instrumentation-django~=0.49b0->azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: opentelemetry-util-http==0.51b0 in c:\users\sarat\anaconda3\lib\site-packages (from opentelemetry-instrumentation-django~=0.49b0->azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\sarat\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.51b0->opentelemetry-instrumentation-django~=0.49b0->azure-monitor-opentelemetry->azure-ai-ml) (1.14.1)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\sarat\anaconda3\lib\site-packages (from opentelemetry-api<2.0.0,>=1.12.0->azure-core-tracing-opentelemetry~=1.0.0b11->azure-monitor-opentelemetry->azure-ai-ml) (7.0.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.51b0 in c:\users\sarat\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi~=0.49b0->azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\sarat\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi~=0.49b0->azure-monitor-opentelemetry->azure-ai-ml) (3.8.1)
# Requirement already satisfied: opentelemetry-instrumentation-dbapi==0.51b0 in c:\users\sarat\anaconda3\lib\site-packages (from opentelemetry-instrumentation-psycopg2~=0.49b0->azure-monitor-opentelemetry->azure-ai-ml) (0.51b0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\sarat\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.26.4)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sarat\anaconda3\lib\site-packages (from pandas<3.0.0,>=1.5.3->promptflow-devkit>=1.17.1->azure-ai-evaluation) (2023.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\sarat\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.18->azure-ai-ml) (3.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\sarat\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=1.4.48->promptflow-devkit>=1.17.1->azure-ai-evaluation) (3.0.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\sarat\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4.0.0,>=3.1.24->promptflow-devkit>=1.17.1->azure-ai-evaluation) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sarat\anaconda3\lib\site-packages (from Jinja2>=3.1.2->flask<4.0.0,>=2.2.3->promptflow-core>=1.17.1->azure-ai-evaluation) (2.1.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sarat\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.17.1->azure-ai-evaluation) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\sarat\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi<1.0.0,>=0.109.0->promptflow-core>=1.17.1->azure-ai-evaluation) (2.27.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sarat\anaconda3\lib\site-packages (from anyio->httpx>=0.25.1->promptflow-devkit>=1.17.1->azure-ai-evaluation) (1.3.0)
# Requirement already satisfied: more-itertools in c:\users\sarat\anaconda3\lib\site-packages (from jaraco.classes->keyring<25.0.0,>=24.2.0->promptflow-devkit>=1.17.1->azure-ai-evaluation) (10.1.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\sarat\anaconda3\lib\site-packages (from openai->promptflow-tracing==1.17.2->promptflow-core>=1.17.1->azure-ai-evaluation) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\sarat\anaconda3\lib\site-packages (from openai->promptflow-tracing==1.17.2->promptflow-core>=1.17.1->azure-ai-evaluation) (0.8.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\sarat\anaconda3\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api<2.0.0,>=1.12.0->azure-core-tracing-opentelemetry~=1.0.0b11->azure-monitor-opentelemetry->azure-ai-ml) (3.17.0)
# Using cached azure_ai_evaluation-1.3.0-py3-none-any.whl (583 kB)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Using cached promptflow_core-1.17.2-py3-none-any.whl (987 kB)
# Using cached promptflow_tracing-1.17.2-py3-none-any.whl (26 kB)
# Using cached promptflow_devkit-1.17.2-py3-none-any.whl (7.0 MB)
# Using cached pydash-7.0.7-py3-none-any.whl (110 kB)
# Downloading argcomplete-3.5.3-py3-none-any.whl (43 kB)
#    ---------------------------------------- 0.0/43.6 kB ? eta -:--:--
#    ---------------------------------------- 43.6/43.6 kB 2.2 MB/s eta 0:00:00
# Downloading fastapi-0.115.9-py3-none-any.whl (94 kB)
#    ---------------------------------------- 0.0/94.9 kB ? eta -:--:--
#    ---------------------------------------- 94.9/94.9 kB 5.6 MB/s eta 0:00:00
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached flask_cors-5.0.1-py3-none-any.whl (11 kB)
# Using cached flask_restx-1.3.0-py2.py3-none-any.whl (2.8 MB)
# Using cached opentelemetry_exporter_otlp_proto_http-1.30.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.30.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.30.0-py3-none-any.whl (55 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading waitress-3.0.2-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.2 kB ? eta -:--:--
#    ---------------------------------------- 56.2/56.2 kB 3.1 MB/s eta 0:00:00
# Using cached docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading aniso8601-10.0.0-py2.py3-none-any.whl (52 kB)
#    ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#    ---------------------------------------- 52.8/52.8 kB 2.8 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.68.0-py2.py3-none-any.whl (164 kB)
#    ---------------------------------------- 0.0/165.0 kB ? eta -:--:--
#    --------------------------------------- 165.0/165.0 kB 10.3 MB/s eta 0:00:00
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.5 kB ? eta -:--:--
#    ---------------------------------------- 71.5/71.5 kB ? eta 0:00:00
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached protobuf-5.29.3-cp310-abi3-win_amd64.whl (434 kB)
# Installing collected packages: filetype, aniso8601, waitress, python-dotenv, pydash, protobuf, importlib-resources, docstring_parser, argcomplete, starlette, opentelemetry-proto, nltk, googleapis-common-protos, opentelemetry-exporter-otlp-proto-common, flask-cors, fastapi, flask-restx, promptflow-tracing, opentelemetry-exporter-otlp-proto-http, promptflow-core, promptflow-devkit, azure-ai-evaluation
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 0.21.0
#     Uninstalling python-dotenv-0.21.0:
#       Successfully uninstalled python-dotenv-0.21.0
#   Attempting uninstall: pydash
#     Found existing installation: pydash 8.0.5
#     Uninstalling pydash-8.0.5:
#       Successfully uninstalled pydash-8.0.5
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# Successfully installed aniso8601-10.0.0 argcomplete-3.5.3 azure-ai-evaluation-1.3.0 docstring_parser-0.16 fastapi-0.115.9 filetype-1.2.0 flask-cors-5.0.1 flask-restx-1.3.0 googleapis-common-protos-1.68.0 importlib-resources-6.5.2 nltk-3.9.1 opentelemetry-exporter-otlp-proto-common-1.30.0 opentelemetry-exporter-otlp-proto-http-1.30.0 opentelemetry-proto-1.30.0 promptflow-core-1.17.2 promptflow-devkit-1.17.2 promptflow-tracing-1.17.2 protobuf-5.29.3 pydash-7.0.7 python-dotenv-1.0.1 starlette-0.45.3 waitress-3.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.32.0 requires protobuf<5,>=3.20, but you have protobuf 5.29.3 which is incompatible.

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- ------------------
# aiobotocore                              2.12.3
# aiohttp                                  3.9.5
# aioitertools                             0.7.1
# aiosignal                                1.2.0
# alabaster                                0.7.16
# altair                                   5.0.1
# anaconda-anon-usage                      0.4.4
# anaconda-catalogs                        0.2.0
# anaconda-client                          1.12.3
# anaconda-cloud-auth                      0.5.1
# anaconda-navigator                       2.6.0
# anaconda-project                         0.11.1
# aniso8601                                10.0.0
# annotated-types                          0.6.0
# anyio                                    4.2.0
# appdirs                                  1.4.4
# archspec                                 0.2.3
# argcomplete                              3.5.3
# argon2-cffi                              21.3.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.2.3
# asgiref                                  3.8.1
# astroid                                  2.14.2
# astropy                                  6.1.0
# astropy-iers-data                        0.2024.6.3.0.31.14
# asttokens                                2.0.5
# async-lru                                2.0.4
# asyncer                                  0.0.8
# atomicwrites                             1.4.0
# attrs                                    23.1.0
# Automat                                  20.2.0
# autopep8                                 2.0.4
# azure-ai-evaluation                      1.3.0
# azure-ai-inference                       1.0.0b9
# azure-ai-ml                              1.25.0
# azure-ai-projects                        1.0.0b6
# azure-common                             1.1.28
# azure-core                               1.32.0
# azure-core-tracing-opentelemetry         1.0.0b11
# azure-cosmos                             4.9.0
# azure-identity                           1.20.0
# azure-mgmt-core                          1.5.0
# azure-monitor-opentelemetry              1.6.5
# azure-monitor-opentelemetry-exporter     1.0.0b34
# azure-search-documents                   11.6.0b9
# azure-storage-blob                       12.24.1
# azure-storage-file-datalake              12.18.1
# azure-storage-file-share                 12.20.1
# Babel                                    2.11.0
# bcrypt                                   3.2.0
# beautifulsoup4                           4.12.3
# binaryornot                              0.4.4
# black                                    24.4.2
# bleach                                   4.1.0
# blinker                                  1.6.2
# bokeh                                    3.4.1
# boltons                                  23.0.0
# botocore                                 1.34.69
# Bottleneck                               1.3.7
# Brotli                                   1.0.9
# cachetools                               5.3.3
# certifi                                  2024.6.2
# cffi                                     1.16.0
# chardet                                  4.0.0
# charset-normalizer                       2.0.4
# click                                    8.1.7
# cloudevents                              1.11.0
# cloudpickle                              2.2.1
# colorama                                 0.4.6
# colorcet                                 3.1.0
# comm                                     0.2.1
# conda                                    24.5.0
# conda-build                              24.5.1
# conda-content-trust                      0.2.0
# conda_index                              0.5.0
# conda-libmamba-solver                    24.1.0
# conda-pack                               0.7.1
# conda-package-handling                   2.3.0
# conda_package_streaming                  0.10.0
# conda-repo-cli                           1.0.88
# conda-token                              0.5.0+1.g2209e04
# constantly                               23.10.4
# contourpy                                1.2.0
# cookiecutter                             2.6.0
# cryptography                             42.0.5
# cssselect                                1.2.0
# cycler                                   0.11.0
# cytoolz                                  0.12.2
# dask                                     2024.5.0
# dask-expr                                1.1.0
# datashader                               0.16.2
# debugpy                                  1.6.7
# decorator                                5.1.1
# defusedxml                               0.7.1
# Deprecated                               1.2.18
# deprecation                              2.1.0
# diff-match-patch                         20200713
# dill                                     0.3.8
# diskcache                                5.6.3
# distributed                              2024.5.0
# distro                                   1.9.0
# docker                                   7.1.0
# docstring_parser                         0.16
# docstring-to-markdown                    0.11
# docutils                                 0.18.1
# entrypoints                              0.4
# et-xmlfile                               1.1.0
# executing                                0.8.3
# fast-depends                             2.4.12
# fastapi                                  0.115.9
# fastjsonschema                           2.16.2
# filelock                                 3.13.1
# filetype                                 1.2.0
# fixedint                                 0.1.6
# flake8                                   7.0.0
# Flask                                    3.0.3
# flask-cors                               5.0.1
# flask-restx                              1.3.0
# fonttools                                4.51.0
# frozendict                               2.4.2
# frozenlist                               1.4.0
# fsspec                                   2024.3.1
# gensim                                   4.3.2
# gitdb                                    4.0.7
# GitPython                                3.1.37
# googleapis-common-protos                 1.68.0
# greenlet                                 3.0.1
# grpcio                                   1.66.1
# h11                                      0.14.0
# h5py                                     3.11.0
# HeapDict                                 1.0.1
# holoviews                                1.19.0
# httpcore                                 1.0.7
# httpx                                    0.28.1
# hvplot                                   0.10.0
# hyperlink                                21.0.0
# idna                                     3.7
# imagecodecs                              2023.1.23
# imageio                                  2.33.1
# imagesize                                1.4.1
# imbalanced-learn                         0.12.3
# importlib-metadata                       7.0.1
# importlib_resources                      6.5.2
# incremental                              22.10.0
# inflection                               0.5.1
# iniconfig                                1.1.1
# intake                                   0.7.0
# intervaltree                             3.1.0
# ipykernel                                6.28.0
# ipython                                  8.25.0
# ipython-genutils                         0.2.0
# ipywidgets                               7.8.1
# isodate                                  0.7.2
# isort                                    5.13.2
# itemadapter                              0.3.0
# itemloaders                              1.1.0
# itsdangerous                             2.2.0
# jaraco.classes                           3.2.1
# jedi                                     0.18.1
# jellyfish                                1.0.1
# Jinja2                                   3.1.4
# jiter                                    0.8.2
# jmespath                                 1.0.1
# joblib                                   1.4.2
# json5                                    0.9.6
# jsonpatch                                1.33
# jsonpointer                              2.1
# jsonschema                               4.19.2
# jsonschema-path                          0.3.4
# jsonschema-specifications                2023.7.1
# jupyter                                  1.0.0
# jupyter_client                           8.6.0
# jupyter-console                          6.6.3
# jupyter_core                             5.7.2
# jupyter-events                           0.10.0
# jupyter-lsp                              2.2.0
# jupyter_server                           2.14.1
# jupyter_server_terminals                 0.4.4
# jupyterlab                               4.0.11
# jupyterlab-pygments                      0.1.2
# jupyterlab_server                        2.25.1
# jupyterlab-widgets                       1.0.0
# keyring                                  24.3.1
# kiwisolver                               1.4.4
# lazy_loader                              0.4
# lazy-object-proxy                        1.10.0
# lckr_jupyterlab_variableinspector        3.1.0
# libarchive-c                             2.9
# libmambapy                               1.5.8
# linkify-it-py                            2.0.0
# llvmlite                                 0.42.0
# lmdb                                     1.4.1
# locket                                   1.0.0
# lxml                                     5.2.1
# lz4                                      4.3.2
# Markdown                                 3.4.1
# markdown-it-py                           2.2.0
# MarkupSafe                               2.1.3
# marshmallow                              3.26.1
# matplotlib                               3.8.4
# matplotlib-inline                        0.1.6
# mccabe                                   0.7.0
# mdit-py-plugins                          0.3.0
# mdurl                                    0.1.0
# menuinst                                 2.1.1
# mistune                                  2.0.4
# mkl-fft                                  1.3.8
# mkl-random                               1.2.4
# mkl-service                              2.4.0
# more-itertools                           10.1.0
# mpmath                                   1.3.0
# msal                                     1.31.1
# msal-extensions                          1.2.0
# msgpack                                  1.0.3
# msrest                                   0.7.1
# multidict                                6.0.4
# multipledispatch                         0.6.0
# mypy                                     1.10.0
# mypy-extensions                          1.0.0
# navigator-updater                        0.5.1
# nbclient                                 0.8.0
# nbconvert                                7.10.0
# nbformat                                 5.9.2
# nest-asyncio                             1.6.0
# networkx                                 3.2.1
# nltk                                     3.9.1
# notebook                                 7.0.8
# notebook_shim                            0.2.3
# numba                                    0.59.1
# numexpr                                  2.8.7
# numpy                                    1.26.4
# numpydoc                                 1.7.0
# oauthlib                                 3.2.2
# openai                                   1.65.1
# openapi-core                             0.19.4
# openapi-schema-validator                 0.6.3
# openapi-spec-validator                   0.7.1
# openpyxl                                 3.1.2
# opentelemetry-api                        1.30.0
# opentelemetry-exporter-otlp-proto-common 1.30.0
# opentelemetry-exporter-otlp-proto-http   1.30.0
# opentelemetry-instrumentation            0.51b0
# opentelemetry-instrumentation-asgi       0.51b0
# opentelemetry-instrumentation-dbapi      0.51b0
# opentelemetry-instrumentation-django     0.51b0
# opentelemetry-instrumentation-fastapi    0.51b0
# opentelemetry-instrumentation-flask      0.51b0
# opentelemetry-instrumentation-psycopg2   0.51b0
# opentelemetry-instrumentation-requests   0.51b0
# opentelemetry-instrumentation-urllib     0.51b0
# opentelemetry-instrumentation-urllib3    0.51b0
# opentelemetry-instrumentation-wsgi       0.51b0
# opentelemetry-proto                      1.30.0
# opentelemetry-resource-detector-azure    0.1.5
# opentelemetry-sdk                        1.30.0
# opentelemetry-semantic-conventions       0.51b0
# opentelemetry-util-http                  0.51b0
# overrides                                7.4.0
# packaging                                23.2
# pandas                                   2.2.2
# pandocfilters                            1.5.0
# panel                                    1.4.4
# param                                    2.1.0
# paramiko                                 2.8.1
# parse                                    1.20.2
# parsel                                   1.8.1
# parso                                    0.8.3
# partd                                    1.4.1
# pathable                                 0.4.4
# pathspec                                 0.10.3
# patsy                                    0.5.6
# pexpect                                  4.8.0
# pickleshare                              0.7.5
# pillow                                   10.3.0
# pip                                      24.0
# pkce                                     1.0.3
# pkginfo                                  1.10.0
# platformdirs                             3.10.0
# plotly                                   5.22.0
# pluggy                                   1.0.0
# ply                                      3.11
# portalocker                              2.10.1
# prance                                   23.6.21.0
# prometheus-client                        0.14.1
# prompt-toolkit                           3.0.43
# promptflow-core                          1.17.2
# promptflow-devkit                        1.17.2
# promptflow-tracing                       1.17.2
# Protego                                  0.1.16
# protobuf                                 5.29.3
# psutil                                   5.9.0
# ptyprocess                               0.7.0
# pure-eval                                0.2.2
# py-cpuinfo                               9.0.0
# pyarrow                                  14.0.2
# pyasn1                                   0.4.8
# pyasn1-modules                           0.2.8
# pyautogen                                0.7.6
# pybars4                                  0.9.13
# pycodestyle                              2.11.1
# pycosat                                  0.6.6
# pycparser                                2.21
# pyct                                     0.5.0
# pycurl                                   7.45.2
# pydantic                                 2.10.6
# pydantic_core                            2.27.2
# pydantic-settings                        2.8.1
# pydash                                   7.0.7
# pydeck                                   0.8.0
# PyDispatcher                             2.0.5
# pydocstyle                               6.3.0
# pyerfa                                   2.0.1.4
# pyflakes                                 3.2.0
# Pygments                                 2.15.1
# PyJWT                                    2.8.0
# pylint                                   2.16.2
# pylint-venv                              3.0.3
# pyls-spyder                              0.4.0
# PyMeta3                                  0.5.1
# PyNaCl                                   1.5.0
# pyodbc                                   5.0.1
# pyOpenSSL                                24.0.0
# pyparsing                                3.0.9
# PyQt5                                    5.15.10
# PyQt5-sip                                12.13.0
# PyQtWebEngine                            5.15.6
# PySocks                                  1.7.1
# pytest                                   7.4.4
# python-dateutil                          2.9.0.post0
# python-dotenv                            1.0.1
# python-json-logger                       2.0.7
# python-lsp-black                         2.0.0
# python-lsp-jsonrpc                       1.1.2
# python-lsp-server                        1.10.0
# python-slugify                           5.0.2
# python-snappy                            0.6.1
# pytoolconfig                             1.2.6
# pytz                                     2024.1
# pyviz_comms                              3.0.2
# pywavelets                               1.5.0
# pywin32                                  305.1
# pywin32-ctypes                           0.2.2
# pywinpty                                 2.0.10
# PyYAML                                   6.0.1
# pyzmq                                    25.1.2
# QDarkStyle                               3.2.3
# qstylizer                                0.2.2
# QtAwesome                                1.2.2
# qtconsole                                5.5.1
# QtPy                                     2.4.1
# queuelib                                 1.6.2
# referencing                              0.30.2
# regex                                    2023.10.3
# requests                                 2.32.2
# requests-file                            1.5.1
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rich                                     13.3.5
# rope                                     1.12.0
# rpds-py                                  0.10.6
# Rtree                                    1.0.1
# ruamel.yaml                              0.17.21
# ruamel-yaml-conda                        0.17.21
# s3fs                                     2024.3.1
# scikit-image                             0.23.2
# scikit-learn                             1.4.2
# scipy                                    1.15.2
# Scrapy                                   2.11.1
# seaborn                                  0.13.2
# semantic-kernel                          1.22.0
# semver                                   3.0.2
# Send2Trash                               1.8.2
# service-identity                         18.1.0
# setuptools                               69.5.1
# sip                                      6.7.12
# six                                      1.16.0
# smart-open                               5.2.1
# smmap                                    4.0.0
# sniffio                                  1.3.0
# snowballstemmer                          2.2.0
# sortedcontainers                         2.4.0
# soupsieve                                2.5
# Sphinx                                   7.3.7
# sphinxcontrib-applehelp                  1.0.2
# sphinxcontrib-devhelp                    1.0.2
# sphinxcontrib-htmlhelp                   2.0.0
# sphinxcontrib-jsmath                     1.0.1
# sphinxcontrib-qthelp                     1.0.3
# sphinxcontrib-serializinghtml            1.1.10
# spyder                                   5.5.1
# spyder-kernels                           2.5.0
# SQLAlchemy                               2.0.30
# stack-data                               0.2.0
# starlette                                0.45.3
# statsmodels                              0.14.2
# streamlit                                1.32.0
# strictyaml                               1.7.3
# sympy                                    1.12
# tables                                   3.9.2
# tabulate                                 0.9.0
# tblib                                    1.7.0
# tenacity                                 8.2.2
# termcolor                                2.5.0
# terminado                                0.17.1
# text-unidecode                           1.3
# textdistance                             4.2.1
# threadpoolctl                            2.2.0
# three-merge                              0.1.1
# tifffile                                 2023.4.12
# tiktoken                                 0.9.0
# tinycss2                                 1.2.1
# tldextract                               3.2.0
# toml                                     0.10.2
# tomli                                    2.0.1
# tomlkit                                  0.11.1
# toolz                                    0.12.0
# tornado                                  6.4.1
# tqdm                                     4.66.4
# traitlets                                5.14.3
# truststore                               0.8.0
# Twisted                                  23.10.0
# twisted-iocpsupport                      1.0.2
# typing_extensions                        4.12.2
# tzdata                                   2023.3
# uc-micro-py                              1.0.1
# ujson                                    5.10.0
# unicodedata2                             15.1.0
# Unidecode                                1.2.0
# urllib3                                  2.2.2
# w3lib                                    2.1.2
# waitress                                 3.0.2
# watchdog                                 4.0.1
# wcwidth                                  0.2.5
# webencodings                             0.5.1
# websocket-client                         1.8.0
# Werkzeug                                 3.0.3
# whatthepatch                             1.0.2
# wheel                                    0.43.0
# widgetsnbextension                       3.6.6
# win-inet-pton                            1.1.0
# wrapt                                    1.14.1
# xarray                                   2023.6.0
# xgboost                                  2.1.1
# XlsxWriter                               3.2.0
# xlwings                                  0.31.4
# xyzservices                              2022.9.0
# yapf                                     0.40.2
# yarl                                     1.9.3
# zict                                     3.0.0
# zipp                                     3.17.0
# zope.interface                           5.4.0
# zstandard                                0.22.0

# %%
import os
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import (
    Evaluation, Dataset, EvaluatorConfiguration, ConnectionType
)
from azure.ai.evaluation import F1ScoreEvaluator, RelevanceEvaluator, ViolenceEvaluator
from azure.identity import DefaultAzureCredential
from azure.core.exceptions import ServiceResponseError
import time

# 1) Connect to Azure AI Foundry project
project_conn_str = loaded_config.get("PROJECT_CONNECTION_STRING")
credential = DefaultAzureCredential()

project_client = AIProjectClient.from_connection_string(
    credential=credential,
    conn_str=project_conn_str
)
print("✅ Created AIProjectClient.")

# 2) Upload data for evaluation
uploaded_data_id, _ = project_client.upload_file(str(eval_data_path))
print("✅ Uploaded JSONL to project. Data asset ID:", uploaded_data_id)

# 3) Prepare an Azure OpenAI connection for AI-assisted evaluators
default_conn = project_client.connections.get_default(ConnectionType.AZURE_OPEN_AI)

deployment_name = os.environ.get("AOAI_DEPLOYMENT", "gpt-4")
api_version = os.environ.get("AOAI_API_VERSION", "2023-07-01-preview")

# 4) Construct the evaluation object
model_config = default_conn.to_evaluator_model_config(
    deployment_name=deployment_name,
    api_version=api_version
)

evaluation = Evaluation(
    display_name="Health Fitness Remote Evaluation",
    description="Evaluating dataset for correctness.",
    data=Dataset(id=uploaded_data_id),
    evaluators={
        "f1_score": EvaluatorConfiguration(id=F1ScoreEvaluator.id),
        "relevance": EvaluatorConfiguration(
            id=RelevanceEvaluator.id,
            init_params={"model_config": model_config}
        ),
        "violence": EvaluatorConfiguration(
            id=ViolenceEvaluator.id,
            init_params={"azure_ai_project": project_client.scope}
        )
    }
)

# Helper: Create evaluation with retry logic
def create_evaluation_with_retry(project_client, evaluation, max_retries=3, retry_delay=5):
    for attempt in range(max_retries):
        try:
            result = project_client.evaluations.create(evaluation=evaluation)
            return result
        except ServiceResponseError as e:
            if attempt == max_retries - 1:
                raise
            print(f"⚠️ Attempt {attempt+1} failed: {str(e)}. Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)

# 5) Create & track the evaluation using retry logic
cloud_eval = create_evaluation_with_retry(project_client, evaluation)
print("✅ Created evaluation job. ID:", cloud_eval.id)

# 6) Poll or fetch final status
fetched_eval = project_client.evaluations.get(cloud_eval.id)
print("Current status:", fetched_eval.status)
if hasattr(fetched_eval, 'properties'):
    link = fetched_eval.properties.get("AiStudioEvaluationUri", "")
    if link:
        print("View details in Foundry:", link)
else:
    print("No link found.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 26
#      23 print("✅ Uploaded JSONL to project. Data asset ID:", uploaded_data_id)
#      25 # 3) Prepare an Azure OpenAI connection for AI-assisted evaluators
# ---> 26 default_conn = project_client.connections.get_default(ConnectionType.AZURE_OPEN_AI)
#      28 deployment_name = os.environ.get("AOAI_DEPLOYMENT", "gpt-4")
#      29 api_version = os.environ.get("AOAI_API_VERSION", "2023-07-01-preview")
#
# File D:\MLOps\Gen Ai & MLOps Masterclass\Materilas\test\ai-foundry-workshop\.venv\Lib\site-packages\azure\core\tracing\decorator.py:116, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     114 for key, value in func_tracing_attributes.items():
#     115     span.add_attribute(key, value)
# --> 116 return func(*args, **kwargs)
#
# TypeError: ConnectionsOperations.get_default() takes 1 positional argument but 2 were given

# %% [markdown]
# ### Viewing Cloud Evaluation Results
# - Navigate to the **Evaluations** tab in your AI Foundry project to see your evaluation job.
# - Open the evaluation to view aggregated metrics and row-level details.
# - For AI-assisted or risk & safety evaluators, you'll see both average scores and detailed per-row results.

# %% [markdown]
# # 5. Extra Topics
# We'll do a quick overview of some advanced features:
# 1. [Risk & Safety Evaluators](#5.1-Risk-and-Safety)
# 2. [Additional Quality Evaluators](#5.2-Quality)
# 3. [Custom Evaluators](#5.3-Custom)
# 4. [Simulators & Adversarial Data](#5.4-Simulators)

# %% [markdown]
# ## 5.1 Risk & Safety Evaluators
#
# Azure AI Foundry includes built-in evaluators that detect content risks. Examples include:
# - **ViolenceEvaluator**: detects violent or harmful content.
# - **SexualEvaluator**: checks for explicit content.
# - **HateUnfairnessEvaluator**: flags hateful content.
# - **SelfHarmEvaluator**: detects self-harm related content.
# - **ProtectedMaterialEvaluator**: identifies copyrighted or protected content.
#
# These evaluators accept a `query` and `response` (and sometimes `context`) to provide severity labels and scores.
#
# For example:
# ```python
# from azure.ai.evaluation import ViolenceEvaluator
#
# violence_eval = ViolenceEvaluator(
#     credential=DefaultAzureCredential(),
#     azure_ai_project={
#         "subscription_id": "...",
#         "resource_group_name": "...",
#         "project_name": "..."
#     }
# )
# result = violence_eval(query="What is the capital of France?", response="Paris")
# print(result)
# ```

# %% [markdown]
# ## 5.2 Additional Quality Evaluators
# Beyond `F1Score` and `Relevance`, there are many built-ins:
# - **GroundednessEvaluator**: Checks if the response is anchored in the provided context.
# - **CoherenceEvaluator**: Measures the logical flow of the response.
# - **FluencyEvaluator**: Assesses grammatical correctness.
#
# These metrics can help you fine-tune your model’s performance.

# %% [markdown]
# ## 5.3 Custom Evaluators
# You can build your own evaluators. For instance, a simple evaluator that measures the length of a response:
# ```python
# class AnswerLengthEvaluator:
#     def __call__(self, response: str, **kwargs):
#         return {"answer_length": len(response)}
# ```
#
# You can then integrate it with the local or cloud evaluation workflow.

# %% [markdown]
# ## 5.4 Simulators & Adversarial Data
# If you need to generate synthetic or adversarial evaluation data, the `azure-ai-evaluation` package provides simulators.
#
# For example, you can simulate adversarial queries using `AdversarialSimulator` to test model safety and robustness.

# %% [markdown]
# # 6. Conclusion 🏁
#
# We covered:
# 1. **Local** evaluations with `evaluate(...)` on JSONL data (now including a groundedness metric).
# 2. **Cloud** evaluations with `AIProjectClient` including retry logic for robustness.
# 3. Built-in **risk & safety** and **quality** evaluators.
# 4. **Custom** evaluators for advanced scenarios.
# 5. **Simulators** for generating adversarial data.
#
# **Next Steps**:
# - Adjust your model and prompts based on evaluation feedback.
# - Integrate these evaluations into your CI/CD pipelines.
# - Combine with observability tools for deeper insights.
#
# > **Best of luck** building robust and responsible AI solutions with Azure AI Foundry!
